# %%
import json
import os
import pandas as pd
# Out:
# C:\Users\olumi\AppData\Local\Temp\ipykernel_9352\948080911.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
j_file = r"D:\ETL-Pipeline\input_data\tech_assessment_transactions.json"
with open(j_file, 'r') as file:
    data = json.load(file)
    transactions = data.get('transactions', [])
    df = pd.DataFrame(transactions)

# %%
df.head(20)
# Out:
#                               customerId   customerName  \
# 0   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 1   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 2   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 3   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 4   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 5   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 6   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 7   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 8   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 9   fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 10  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 11  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 12  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 13  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 14  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 15  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 16  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 17  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 18  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
# 19  fbbe0690-0cd1-48eb-aece-f2744db6f895  Gregory Downs
#
#                            transactionId transactionDate           sourceDate  \
# 0   7b3c8eee-3689-4cf8-b874-dfbe515d2eb7      2022-02-21  2022-02-22T21:20:48
# 1   3a05ea6b-acb8-4dfe-847e-470b6502bd54      2022-04-03  2022-04-03T19:00:23
# 2   b14a9ac9-c541-4ba9-8bf1-efbaab61d76f      2023-11-11  2023-11-13T04:00:20
# 3   cbd5d46e-09a4-47ce-ba77-6e4806976425      2019-09-12  2019-09-17T14:47:20
# 4   56c304bc-5563-4ec9-b445-fe2a3bf63d64      2021-08-02  2021-08-07T02:00:12
# 5   894afc55-5f97-4224-95a9-775e4350919f      2020-08-16  2020-08-19T20:00:33
# 6   8b5f5cf3-f812-4a48-811a-404bcf803a4b      2021-06-15  2021-06-22T15:56:08
# 7   5923c418-3f27-49fc-9989-9a3bfae8c295      2020-01-03  2020-01-12T05:09:04
# 8   15895ce2-d15c-4c12-8621-78273b6b8805      2019-10-16  2019-10-21T20:52:59
# 9   875b25fc-bc9c-4fd6-9608-d8ba13d7290a      2020-07-18  2020-07-22T14:57:00
# 10  def4e517-6ec6-4171-b2f8-a36445fcc51b      2021-12-27  2022-01-03T10:57:18
# 11  2537dfa5-3635-4500-b2ab-9fdaf424e644      2023-09-24  2023-10-01T19:25:09
# 12  ae9a095b-a288-4263-9ecf-396f066e3d23      2021-11-20  2021-11-28T16:12:31
# 13  0185ba7c-ee1a-482d-a00b-b8ed5f1b2180      2021-09-30  2021-10-04T20:25:46
# 14  cfc81abd-dddb-4025-ae70-66c2f743033b      2021-01-28  2021-02-05T13:34:37
# 15  810a86f8-32ed-40de-8df3-408f506932d7      2020-02-03  2020-02-08T19:34:52
# 16  55e81790-e0b1-47fd-90bf-6a48ab342b6d      2019-01-31  2019-02-07T10:53:47
# 17  ccfd8794-68a9-42de-82e2-f82151392693      2021-09-19  2021-09-21T03:46:16
# 18  92707dc8-c284-4190-a9e3-979ff661eb1f      2021-10-30  2021-11-08T17:02:59
# 19  5563e254-32e1-415c-adb4-ff79a36f6389      2020-07-29  2020-08-02T13:10:25
#
#     merchantId  categoryId currency    amount  \
# 0           36          10      GBP  -1841.11
# 1           64           3      GBP    594.59
# 2           61           4      GBP   -656.25
# 3           86           8      GBP  -1329.37
# 4           64           3      GBP    247.15
# 5           28           9      GBP   -362.43
# 6            7          11      GBP      9.25
# 7           13           9      GBP   1406.95
# 8           97           2      GBP   2022.26
# 9           41          11      GBP  -2112.24
# 10          93          10      GBP    -416.7
# 11          72           5      GBP   -671.52
# 12          48           6      GBP   -399.22
# 13          29           1      GBP   -587.75
# 14           4           5      GBP    463.37
# 15          72           5      GBP  -1660.79
# 16          62           5      GBP   1451.61
# 17          98           8      GBP   -193.11
# 18          59           4      GBP   -251.24
# 19          46           7      GBP   1708.74
#
#                                   description
# 0                        Blair-White | Travel
# 1                     Sherman-Love | Shopping
# 2   Anderson, Thomas and Jimenez | Eating Out
# 3           Smith, Owens and Lewis | Finances
# 4                     Sherman-Love | Shopping
# 5                 Casey Inc | Health & Beauty
# 6                Henderson and Sons | General
# 7               Palmer-Ward | Health & Beauty
# 8                     Gray-Meyers | Groceries
# 9                 Bradley-Robertson | General
# 10                      Anderson Ltd | Travel
# 11             Martin-Bonilla | Entertainment
# 12                  Smith LLC | Home & Family
# 13                  Bennett Group | Transport
# 14             Evans and Sons | Entertainment
# 15             Martin-Bonilla | Entertainment
# 16   Steele, Myers and Gordon | Entertainment
# 17           Hayes, Moran and Hill | Finances
# 18                  Grimes-Payne | Eating Out
# 19                        Brady Inc | Charity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6869 entries, 0 to 6868
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerId       6869 non-null   object
#  1   customerName     6869 non-null   object
#  2   transactionId    6869 non-null   object
#  3   transactionDate  6869 non-null   object
#  4   sourceDate       6869 non-null   object
#  5   merchantId       6869 non-null   int64
#  6   categoryId       6869 non-null   int64
#  7   currency         6869 non-null   object
#  8   amount           6869 non-null   object
#  9   description      6869 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 536.8+ KB

# %%
df_filtered = df.drop_duplicates(subset=['customerId','transactionId'])
df_filtered.shape
# Out:
# (6861, 10)

# %%
df_filtered[~df_filtered['currency'].isin() ]

# %%
# Out:
# customerId         6869
# customerName       6869
# transactionId      6869
# transactionDate    6869
# sourceDate         6869
# merchantId         6869
# categoryId         6869
# currency           6869
# amount             6869
# description        6869
# dtype: int64
